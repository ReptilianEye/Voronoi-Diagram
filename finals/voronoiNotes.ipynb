# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from voronoi import Voronoi

# %%
points = [(0, 0), (1, 1), (2, 3), (-1, 2.5)]

# %%
vor = Voronoi(points)
vor_edges, box, vis = vor.get_voronoi_visualised()
vis.show()

# %%
vor = Voronoi(points)
vor_edges, box, vis = vor.get_voronoi_visualised()
print(vor_edges)
print(box)
vis.show()
# Out:
# [((0.5454545454545445, 2.4772727272727284), (0.29166666666666563, 4.0)), ((1, 2.25), (0.5454545454545445, 2.4772727272727284)), ((0.5454545454545445, 2.4772727272727284), (-0.3214285714285714, 1.3214285714285718)), ((0, 1.0), (-0.3214285714285714, 1.3214285714285718)), ((-0.3214285714285714, 1.3214285714285718), (-2.0, 0.6500000000000004)), ((0, 1.0), (2.0, -1.0)), ((1, 2.25), (3.0, 1.2499999999999991))]
# [Point(-2.000, -1.000), Point(3.000, 4.000)]

# %%
def generate_uniform_points(left, right, n=10 ** 5):
    """
    Funkcja generuje równomiernie n punktów na kwadratowym obszarze od left do right (jednakowo na osi y) o współrzędnych rzeczywistych
    :param left:  lewy kraniec przedziału
    :param right: prawy kraniec przedziału
    :param n: ilość generowanych punktów
    :return: tablica punktów w postaci krotek współrzędnych np. [(x1, y1), (x2, y2), ... (xn, yn)]
    """
    return [np.random.uniform(left, right, 2) for _ in range(n)]

# %%
points = [
    [-4.98119373, 6.83857958],
    [-0.12778136, 6.63343697],
    [-7.33037151, 5.50546613],
    [-2.07501278, 3.20578633],
    [5.8388661, -1.68896804],
    [-3.99228758, -3.77928136],
    [9.74501677, -6.04110336],
    [0.98573669, -6.81810449],
    [5.1283655, -9.2936127],
    [8.95603584, -9.51014394],
]

# %%
vor = Voronoi(points)
vor_edges, box, vis = vor.get_voronoi_visualised()
vis.show()

# %%
points = [
    [4.96831207, 8.73658474],
    [6.22802217, 7.48316626],
    [-8.29046443,  7.37948215],
    [-3.37043045,  6.46386103],
    [-0.07248632,  5.59788407],
    [5.52752604, 5.14825604],
    [2.28804169, 1.45765516],
    [-9.30751046, -1.86483428],
    [-5.62135049, -3.04411673],
    [9.81332147, -6.06372514],]

# %%
vor = Voronoi(points)
vor_edges, box, vis = vor.get_voronoi_visualised()
vis.show()

# %%
# vis.show_gif()

# %%
points = generate_uniform_points(-10, 10, 200)
vor = Voronoi(points)
vor_edges, box, vis = vor.get_voronoi_visualised()
vis.show()

# %%
for i in range(10):
    points = generate_uniform_points(-10, 10, 10)
    vor = Voronoi(points)
    vor_edges, box, vis = vor.get_voronoi_visualised()
    vis.show()

# %% [markdown]
# ### Przypadek brzegowy - wszystkie punkty w pionowej lini

# %%
verticalPoints = [
    (0, 10),
    (0, 9),
    (0, 8),
    (0, 7),
    (0, 6),
    (0, 5),
    (0, 4),
    (0, 3),
    (0, 2),
    (0, 1),
]
vor = Voronoi(verticalPoints)
vor_edges, box, vis = vor.get_voronoi_visualised()
vis.show()
# vis.show_gif()
